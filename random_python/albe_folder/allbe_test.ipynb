# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/Users/andreatitton/unox/unox_sample.csv')

# %%
df['datetime'] = df['datetime'].apply(lambda x: pd.Timestamp(x))

# %%
df
# Out:
#                      CHAMBER TEMPERATURE  PROBE TEMPERATURE  SET TEMPERATURE  \
# datetime
# 2018-05-07 05:32:30                   38                 33             99.5
# 2018-05-07 05:33:00                   50                 46             99.5
# 2018-05-07 05:33:30                   66                 61             99.5
# 2018-05-07 05:34:00                   84                 81             99.5
# 2018-05-07 05:34:30                   97                 99             99.5
# 2018-05-07 05:35:00                  108                114             99.5
# 2018-05-07 05:35:30                  110                120             99.5
# 2018-05-07 05:36:00                  110                120             99.5
# 2018-05-07 05:36:30                  107                116             99.5
# 2018-05-07 05:37:00                  104                112             99.5
# 2018-05-07 05:37:30                  102                107             99.5
# ...

# %%
df = df.set_index('datetime')
